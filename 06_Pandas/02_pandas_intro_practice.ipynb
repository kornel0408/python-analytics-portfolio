# %%
# ============================
#     Practice
# ===========================

# %%
# Create this dataset:

# Product	Price	Quantity
# A	        100	        10
# B      	200	        5
# C	        150	        8

# %%
import pandas as pd

# %%
products = {
    "product" : ['A', 'B', 'C'],
    "Price" : [100, 200, 150],
    "Quantity" : [10, 5, 8]
}

# %%
# Task 1:
# Create DataFrame

df = pd.DataFrame(products)
print(df)
# Out:
#   product  Price  Quantity
# 0       A    100        10
# 1       B    200         5
# 2       C    150         8

# %%
# Task 2:

# Print:
# shape
# columns
# data types

# %%
shape = df.shape
print("Shape of the table =", shape)

columns = df.columns
print("Columns of the table = ", columns)

data_types = df.dtypes
print("Data types of the columns =\n", data_types)
# Out:
# Shape of the table = (3, 3)
# Columns of the table =  Index(['product', 'Price', 'Quantity'], dtype='object')
# Data types of the columns =
#  product     object
# Price        int64
# Quantity     int64
# dtype: object

# %%
# Task 3:
# Add new column:
# Revenue = Price × Quantity

# %%
df["Revenue"] = df["Price"]*df["Quantity"] 
print(df)
# Out:
#   product  Price  Quantity  Revenue
# 0       A    100        10     1000
# 1       B    200         5     1000
# 2       C    150         8     1200

# %%
# Task 4:
# Print only Price column

# %%
price_col = df["Price"]
print(price_col)
# Out:
# 0    100
# 1    200
# 2    150
# Name: Price, dtype: int64

# %%
# Task 5:
# Add Discount column

# %%
df["Discount%"] = [5, 7, 15]
print(df)
# Out:
#   product  Price  Quantity  Revenue  Discount%
# 0       A    100        10     1000          5
# 1       B    200         5     1000          7
# 2       C    150         8     1200         15

# %%
# ==================================================
#     Dataset for Practice (E-commerce Products)
# ==================================================

# %%
import pandas as pd

data = {
    "Product": ["Laptop", "Mobile", "Tablet", "Headphones", "Smartwatch"],
    "Price": [60000, 20000, 30000, 2000, 5000],
    "Quantity": [5, 10, 7, 20, 15]
}

dmart = pd.DataFrame(data)

# %%
# Task 1 — Basic Info

# Print:
# Shape of dataset
# Column names
# Data types

# %%
print("shape of the dataset :")
print(dmart.shape)
print("column names :\n", dmart.columns)
print("Data types:\n", dmart.dtypes)
# Out:
# shape of the dataset :
# (5, 3)
# column names :
#  Index(['Product', 'Price', 'Quantity'], dtype='object')
# Data types:
#  Product     object
# Price        int64
# Quantity     int64
# dtype: object

# %%
# Task 2 — Column Access
# Print only Price column
# Print only Product column

# %%
print(dmart["Price"])
print(dmart["Product"])
# Out:
# 0    60000
# 1    20000
# 2    30000
# 3     2000
# 4     5000
# Name: Price, dtype: int64
# 0        Laptop
# 1        Mobile
# 2        Tablet
# 3    Headphones
# 4    Smartwatch
# Name: Product, dtype: object

# %%
# Task 3 — Add Constant Column
# Category = "Electronics"

# %%
dmart["Categorie"] = "Electronics"
print(dmart)
# Out:
#       Product  Price  Quantity    Categorie
# 0      Laptop  60000         5  Electronics
# 1      Mobile  20000        10  Electronics
# 2      Tablet  30000         7  Electronics
# 3  Headphones   2000        20  Electronics
# 4  Smartwatch   5000        15  Electronics

# %%
# Task 5 — Add Custom Values Column
# [10, 5, 8, 2, 6]

# %%
dmart["Discount"] = [10, 5, 8, 2, 6]
print(dmart)
# Out:
#       Product  Price  Quantity    Categorie  Discount
# 0      Laptop  60000         5  Electronics        10
# 1      Mobile  20000        10  Electronics         5
# 2      Tablet  30000         7  Electronics         8
# 3  Headphones   2000        20  Electronics         2
# 4  Smartwatch   5000        15  Electronics         6

# %%
# Task 6 — Modify Column
# Increase all prices by 10%

# %%
dmart["Price"] = dmart["Price"] + dmart["Price"] * 10/100
print(dmart)
# Out:
#       Product    Price  Quantity    Categorie  Discount
# 0      Laptop  66000.0         5  Electronics        10
# 1      Mobile  22000.0        10  Electronics         5
# 2      Tablet  33000.0         7  Electronics         8
# 3  Headphones   2200.0        20  Electronics         2
# 4  Smartwatch   5500.0        15  Electronics         6

# %%
# Task 7 — Create New Derived Column
# Final_Price = Price - Discount

# %%
dmart["Final_price"] = dmart["Price"] - dmart["Discount"]
print(dmart)
# Out:
#       Product    Price  Quantity    Categorie  Discount  Final_price
# 0      Laptop  66000.0         5  Electronics        10      65990.0
# 1      Mobile  22000.0        10  Electronics         5      21995.0
# 2      Tablet  33000.0         7  Electronics         8      32992.0
# 3  Headphones   2200.0        20  Electronics         2       2198.0
# 4  Smartwatch   5500.0        15  Electronics         6       5494.0

# %%
# Task 8 — Series Practice
# Create a Series:

# %%
ratings = pd.Series([4.5, 4.0, 4.2, 3.8, 4.3])
dmart["Ratings"] = ratings
print(dmart)
# Out:
#       Product    Price  Quantity    Categorie  Discount  Final_price  Ratings
# 0      Laptop  66000.0         5  Electronics        10      65990.0      4.5
# 1      Mobile  22000.0        10  Electronics         5      21995.0      4.0
# 2      Tablet  33000.0         7  Electronics         8      32992.0      4.2
# 3  Headphones   2200.0        20  Electronics         2       2198.0      3.8
# 4  Smartwatch   5500.0        15  Electronics         6       5494.0      4.3

# %%
# Task 9 — Check Specific Info

# Print:
# First 3 rows
# Last 2 rows

# %%
print("First 3 rows: \n", dmart.head(3))
print("Last 2 rows: \n", dmart.tail(2))
# Out:
# First 3 rows:
#    Product    Price  Quantity    Categorie  Discount  Final_price  Ratings
# 0  Laptop  66000.0         5  Electronics        10      65990.0      4.5
# 1  Mobile  22000.0        10  Electronics         5      21995.0      4.0
# 2  Tablet  33000.0         7  Electronics         8      32992.0      4.2
# Last 2 rows:
#        Product   Price  Quantity    Categorie  Discount  Final_price  Ratings
# 3  Headphones  2200.0        20  Electronics         2       2198.0      3.8
# 4  Smartwatch  5500.0        15  Electronics         6       5494.0      4.3
